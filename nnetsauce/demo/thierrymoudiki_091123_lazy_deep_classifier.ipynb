# %%
# !pip install nnetsauce

# %%
import os
import nnetsauce as ns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer, load_iris, load_wine, load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from time import time

# %% [markdown]
# # 1 - breast cancer data

# %%
data = load_breast_cancer()
X = data.data
y= data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 123)

clf = ns.LazyDeepClassifier(n_layers=3, verbose=0, ignore_warnings=True)
start = time()
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(f"\n\n Elapsed: {time()-start} seconds \n")
model_dictionary = clf.provide_models(X_train, X_test, y_train, y_test)

display(models)
# Out:
# 100%|██████████| 27/27 [00:44<00:00,  1.65s/it]
#  Elapsed: 44.49836850166321 seconds
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# Perceptron                         0.99               0.99     0.99      0.99
# SGDClassifier                      0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# PassiveAggressiveClassifier        0.98               0.98     0.98      0.98
# LogisticRegression                 0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# BaggingClassifier                  0.97               0.97     0.97      0.97
# LabelPropagation                   0.97               0.97     0.97      0.97
# LabelSpreading                     0.97               0.97     0.97      0.97
# AdaBoostClassifier                 0.97               0.97     0.97      0.97
# LinearSVC                          0.97               0.97     0.97      0.97
# KNeighborsClassifier               0.97               0.97     0.97      0.97
# SVC                                0.97               0.96     0.96      0.97
# CalibratedClassifierCV             0.97               0.96     0.96      0.97
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# QuadraticDiscriminantAnalysis      0.96               0.95     0.95      0.96
# LinearDiscriminantAnalysis         0.96               0.95     0.95      0.96
# ExtraTreeClassifier                0.96               0.94     0.94      0.96
# RidgeClassifier                    0.96               0.94     0.94      0.96
# RidgeClassifierCV                  0.96               0.94     0.94      0.96
# GaussianNB                         0.93               0.90     0.90      0.93
# NearestCentroid                    0.93               0.90     0.90      0.93
# NuSVC                              0.93               0.90     0.90      0.93
# BernoulliNB                        0.91               0.89     0.89      0.91
# DummyClassifier                    0.64               0.50     0.50      0.50
#
#                                Time Taken
# Model
# Perceptron                           2.15
# SGDClassifier                        1.99
# RandomForestClassifier               2.76
# PassiveAggressiveClassifier          1.89
# LogisticRegression                   1.14
# ExtraTreesClassifier                 3.13
# BaggingClassifier                    1.62
# LabelPropagation                     1.69
# LabelSpreading                       1.08
# AdaBoostClassifier                   3.42
# LinearSVC                            1.65
# KNeighborsClassifier                 1.07
# SVC                                  1.07
# CalibratedClassifierCV               1.82
# DecisionTreeClassifier               1.50
# QuadraticDiscriminantAnalysis        1.16
# LinearDiscriminantAnalysis           1.39
# ExtraTreeClassifier                  0.83
# RidgeClassifier                      3.15
# RidgeClassifierCV                    1.51
# GaussianNB                           1.50
# NearestCentroid                      3.00
# NuSVC                                1.27
# BernoulliNB                          1.15
# DummyClassifier                      0.96

# %%
model_dictionary["Perceptron"]
# Out:
# CustomClassifier(obj=CustomClassifier(obj=CustomClassifier(obj=Perceptron(random_state=42))))

# %%
print(classification_report(y_test, model_dictionary["Perceptron"].fit(X_train, y_train).predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.99      1.00      0.99        73
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114

# %%
ConfusionMatrixDisplay.from_estimator(model_dictionary["Perceptron"], X_test, y_test)
plt.show()

# %% [markdown]
# # 2 - iris data

# %%
data = load_iris()
X = data.data
y= data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 123)

clf = ns.LazyDeepClassifier(n_layers=3, verbose=0, ignore_warnings=True)
start = time()
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(f"\n\n Elapsed: {time()-start} seconds \n")
model_dictionary = clf.provide_models(X_train, X_test, y_train, y_test)
display(models)
# Out:
# 100%|██████████| 27/27 [00:05<00:00,  4.51it/s]
#  Elapsed: 5.992894172668457 seconds
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# BaggingClassifier                  1.00               1.00    None      1.00
# DecisionTreeClassifier             1.00               1.00    None      1.00
# KNeighborsClassifier               0.97               0.97    None      0.97
# CalibratedClassifierCV             0.97               0.97    None      0.97
# SGDClassifier                      0.97               0.97    None      0.97
# ExtraTreeClassifier                0.97               0.97    None      0.97
# RidgeClassifier                    0.97               0.97    None      0.97
# RidgeClassifierCV                  0.97               0.97    None      0.97
# RandomForestClassifier             0.97               0.97    None      0.97
# LogisticRegression                 0.97               0.97    None      0.97
# LinearSVC                          0.97               0.97    None      0.97
# PassiveAggressiveClassifier        0.93               0.94    None      0.93
# Perceptron                         0.93               0.94    None      0.93
# BernoulliNB                        0.93               0.94    None      0.93
# LabelSpreading                     0.93               0.91    None      0.93
# LabelPropagation                   0.93               0.91    None      0.93
# ExtraTreesClassifier               0.93               0.91    None      0.93
# GaussianNB                         0.90               0.91    None      0.90
# AdaBoostClassifier                 0.90               0.91    None      0.90
# SVC                                0.87               0.88    None      0.87
# NuSVC                              0.87               0.88    None      0.87
# NearestCentroid                    0.87               0.88    None      0.87
# LinearDiscriminantAnalysis         0.63               0.67    None      0.54
# QuadraticDiscriminantAnalysis      0.20               0.33    None      0.07
# DummyClassifier                    0.20               0.33    None      0.07
#
#                                Time Taken
# Model
# BaggingClassifier                    0.18
# DecisionTreeClassifier               0.11
# KNeighborsClassifier                 0.10
# CalibratedClassifierCV               0.24
# SGDClassifier                        0.21
# ExtraTreeClassifier                  0.10
# RidgeClassifier                      1.05
# RidgeClassifierCV                    0.21
# RandomForestClassifier               0.88
# LogisticRegression                   0.14
# LinearSVC                            0.11
# PassiveAggressiveClassifier          0.11
# Perceptron                           0.11
# BernoulliNB                          0.10
# LabelSpreading                       0.31
# LabelPropagation                     0.20
# ExtraTreesClassifier                 0.45
# GaussianNB                           0.10
# AdaBoostClassifier                   0.38
# SVC                                  0.19
# NuSVC                                0.12
# NearestCentroid                      0.10
# LinearDiscriminantAnalysis           0.20
# QuadraticDiscriminantAnalysis        0.11
# DummyClassifier                      0.10

# %%
model_dictionary["BaggingClassifier"]
# Out:
# CustomClassifier(obj=CustomClassifier(obj=CustomClassifier(obj=BaggingClassifier(random_state=42))))

# %%
print(classification_report(y_test, model_dictionary["BaggingClassifier"].fit(X_train, y_train).predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
ConfusionMatrixDisplay.from_estimator(model_dictionary["BaggingClassifier"], X_test, y_test)
plt.show()

# %% [markdown]
# # 3 - wine data

# %%
data = load_wine()
X = data.data
y= data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 123)

clf = ns.LazyDeepClassifier(n_layers=3, verbose=0, ignore_warnings=True)
start = time()
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(f"\n\n Elapsed: {time()-start} seconds \n")
model_dictionary = clf.provide_models(X_train, X_test, y_train, y_test)
display(models)
# Out:
# 100%|██████████| 27/27 [00:05<00:00,  5.09it/s]
#  Elapsed: 5.312330007553101 seconds
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# RidgeClassifierCV                  1.00               1.00    None      1.00
# RidgeClassifier                    1.00               1.00    None      1.00
# Perceptron                         1.00               1.00    None      1.00
# SVC                                0.97               0.98    None      0.97
# SGDClassifier                      0.97               0.98    None      0.97
# CalibratedClassifierCV             0.97               0.98    None      0.97
# PassiveAggressiveClassifier        0.97               0.98    None      0.97
# LogisticRegression                 0.97               0.98    None      0.97
# LinearSVC                          0.97               0.98    None      0.97
# BaggingClassifier                  0.97               0.97    None      0.97
# RandomForestClassifier             0.97               0.97    None      0.97
# LinearDiscriminantAnalysis         0.97               0.97    None      0.97
# LabelSpreading                     0.94               0.94    None      0.94
# LabelPropagation                   0.94               0.94    None      0.94
# ExtraTreesClassifier               0.94               0.94    None      0.94
# KNeighborsClassifier               0.92               0.92    None      0.92
# ExtraTreeClassifier                0.89               0.88    None      0.89
# DecisionTreeClassifier             0.83               0.87    None      0.83
# GaussianNB                         0.86               0.85    None      0.85
# NearestCentroid                    0.86               0.81    None      0.86
# NuSVC                              0.83               0.79    None      0.84
# AdaBoostClassifier                 0.81               0.78    None      0.81
# BernoulliNB                        0.81               0.75    None      0.80
# QuadraticDiscriminantAnalysis      0.53               0.58    None      0.52
# DummyClassifier                    0.31               0.33    None      0.14
#
#                                Time Taken
# Model
# RidgeClassifierCV                    0.15
# RidgeClassifier                      0.13
# Perceptron                           0.15
# SVC                                  0.13
# SGDClassifier                        0.13
# CalibratedClassifierCV               0.27
# PassiveAggressiveClassifier          0.14
# LogisticRegression                   0.16
# LinearSVC                            0.14
# BaggingClassifier                    0.21
# RandomForestClassifier               0.61
# LinearDiscriminantAnalysis           0.16
# LabelSpreading                       0.44
# LabelPropagation                     0.26
# ExtraTreesClassifier                 0.50
# KNeighborsClassifier                 0.13
# ExtraTreeClassifier                  0.13
# DecisionTreeClassifier               0.12
# GaussianNB                           0.13
# NearestCentroid                      0.13
# NuSVC                                0.13
# AdaBoostClassifier                   0.43
# BernoulliNB                          0.15
# QuadraticDiscriminantAnalysis        0.13
# DummyClassifier                      0.13

# %%
model_dictionary["RidgeClassifierCV"]
# Out:
# CustomClassifier(obj=CustomClassifier(obj=CustomClassifier(obj=RidgeClassifierCV())))

# %%
print(classification_report(y_test, model_dictionary["RidgeClassifierCV"].fit(X_train, y_train).predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        17
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
ConfusionMatrixDisplay.from_estimator(model_dictionary["RidgeClassifierCV"], X_test, y_test)
plt.show()

# %% [markdown]
# # 4 - digits data

# %%
data = load_digits()
X = data.data
y= data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 123)

clf = ns.LazyDeepClassifier(n_layers=3, verbose=0, ignore_warnings=True)
start = time()
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(f"\n\n Elapsed: {time()-start} seconds \n")
model_dictionary = clf.provide_models(X_train, X_test, y_train, y_test)
display(models)
# Out:
# 100%|██████████| 27/27 [01:41<00:00,  3.75s/it]
#  Elapsed: 101.15918207168579 seconds
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# SVC                                0.99               0.99    None      0.99
# LogisticRegression                 0.97               0.97    None      0.97
# CalibratedClassifierCV             0.97               0.97    None      0.97
# RandomForestClassifier             0.97               0.97    None      0.97
# LinearDiscriminantAnalysis         0.96               0.96    None      0.96
# LinearSVC                          0.96               0.96    None      0.96
# ExtraTreesClassifier               0.96               0.96    None      0.96
# PassiveAggressiveClassifier        0.96               0.96    None      0.96
# KNeighborsClassifier               0.96               0.96    None      0.96
# SGDClassifier                      0.96               0.96    None      0.96
# RidgeClassifier                    0.94               0.94    None      0.94
# Perceptron                         0.94               0.94    None      0.94
# RidgeClassifierCV                  0.94               0.94    None      0.93
# NuSVC                              0.93               0.93    None      0.93
# BaggingClassifier                  0.92               0.92    None      0.92
# LabelPropagation                   0.91               0.91    None      0.92
# LabelSpreading                     0.91               0.91    None      0.92
# QuadraticDiscriminantAnalysis      0.88               0.88    None      0.88
# NearestCentroid                    0.85               0.85    None      0.85
# DecisionTreeClassifier             0.83               0.83    None      0.83
# BernoulliNB                        0.82               0.82    None      0.82
# GaussianNB                         0.81               0.81    None      0.80
# ExtraTreeClassifier                0.81               0.80    None      0.81
# AdaBoostClassifier                 0.39               0.37    None      0.32
# DummyClassifier                    0.08               0.10    None      0.01
#
#                                Time Taken
# Model
# SVC                                  3.47
# LogisticRegression                   3.67
# CalibratedClassifierCV               8.78
# RandomForestClassifier               4.46
# LinearDiscriminantAnalysis           4.78
# LinearSVC                            4.18
# ExtraTreesClassifier                 3.50
# PassiveAggressiveClassifier          2.89
# KNeighborsClassifier                 3.60
# SGDClassifier                        2.62
# RidgeClassifier                      4.45
# Perceptron                           4.38
# RidgeClassifierCV                    3.02
# NuSVC                                4.55
# BaggingClassifier                    4.84
# LabelPropagation                     2.63
# LabelSpreading                       3.64
# QuadraticDiscriminantAnalysis        2.39
# NearestCentroid                      4.27
# DecisionTreeClassifier               3.36
# BernoulliNB                          2.85
# GaussianNB                           4.63
# ExtraTreeClassifier                  3.35
# AdaBoostClassifier                   5.05
# DummyClassifier                      4.98

# %%
model_dictionary["SVC"]
# Out:
# CustomClassifier(obj=CustomClassifier(obj=CustomClassifier(obj=SVC(random_state=42))))

# %%
print(classification_report(y_test, model_dictionary["SVC"].fit(X_train, y_train).predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       0.94      1.00      0.97        34
#            2       1.00      0.97      0.99        36
#            3       1.00      1.00      1.00        33
#            4       0.95      1.00      0.98        42
#            5       1.00      0.95      0.97        37
#            6       1.00      1.00      1.00        43
#            7       1.00      1.00      1.00        31
#            8       1.00      0.95      0.97        37
#            9       0.97      1.00      0.98        28
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
ConfusionMatrixDisplay.from_estimator(model_dictionary["SVC"], X_test, y_test)
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(model_dictionary["LogisticRegression"], X_test, y_test)
plt.show()
