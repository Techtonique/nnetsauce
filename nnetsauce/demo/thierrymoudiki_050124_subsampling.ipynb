# %% [markdown]
# # Subsampling continous and discrete responses

# %%
import os 
import matplotlib.pyplot as plt
import nnetsauce as ns
import numpy as np
from sklearn.datasets import load_digits, load_diabetes
from time import time


# dataset no. 1 ---------- 

print("\n\n dataset no. 1 (classification) ---------- \n\n")

dataset = load_digits()
u = dataset.target

print(" \n sequential ----- \n")

sub1 = ns.SubSampler(y=u, row_sample=0.6, seed=123, n_jobs=None)
start = time()
x1 = sub1.subsample()
print(f"elapsed time: {time() - start}")

print(x1)

_ = plt.hist(x1, bins='auto')
plt.show()
# Out:
#  dataset no. 1 (classification) ----------
#
#
#
#  sequential -----
#
# creating breaks...
# main loop...
# 100%|██████████| 10/10 [00:00<00:00, 10948.33it/s]
# elapsed time: 0.005174875259399414
# [1099 1283  656 ...  807  942  655]

# %%
print(" \n parallel ----- \n") # needs more data to be efficient

sub2 = ns.SubSampler(y=u, row_sample=0.6, seed=123, n_jobs=2)
start = time()
x2 = sub2.subsample()
print(f"elapsed time: {time() - start}")

print(x2)

print(f" \n check: {np.allclose(x1, x2)} \n")

_ = plt.hist(x2, bins='auto')
plt.show()
# Out:
#
#  parallel -----
#
# creating breaks...
# main loop...
# 100%|██████████| 10/10 [00:00<00:00, 972.41it/s]
# elapsed time: 0.04234480857849121
# [1099 1283  656 ...  807  942  655]
#
#  check: True

# %%
# dataset no. 2 ---------- 

print("\n\n dataset no. 2 (regression) ---------- \n\n")

dataset = load_diabetes()
v = dataset.target

print(" \n sequential ----- \n")

sub1 = ns.SubSampler(y=v, row_sample=0.6, seed=123, n_jobs=None)
start = time()
y1 = sub1.subsample()
print(f"elapsed time: {time() - start}")

print(y1)

_ = plt.hist(y1, bins='auto')
plt.show()
# Out:
#  dataset no. 2 (regression) ----------
#
#
#
#  sequential -----
#
# creating breaks...
# main loop...
# 100%|██████████| 10/10 [00:00<00:00, 13967.05it/s]
# elapsed time: 0.0040683746337890625
# [ 45 356 419 201 229 259 417 396  82 396 396 294 229 156 436 396 170  57
#   56  45 243  45 433 171 109  33 363 236 352 133 171 433 136 136 334 393
#  258 269  42 393 351 352 363 111 196 431 242 355 299 237  22 301 355 292
#  189 189 242 224 383 406 289 226 288 236 370 157 181  11 435 214 401 158
#  438 267 388 424 221 140 173 339 381   5 318 185 173 429  53  14 339 308
#  275  40 148 261  53  18 227 199  98 205 261 308 127 426 381 110 388 193
#   35 128 253 320  55   2   6  87  17  66  49 374  96 407 198 175 179  55
#  411  28  87 374 100 298 326 374   6 345 420  63 374 149 439  96 149 368
#   17  80 147  59 284 219 311  16 228 208  59 311 162 342 191 437 125 122
#   59 409 219  91  19 311 409 432 307  69 313 208 228 437 284 218 225 397
#  218 155 371 244 249 159 207  83 154   3 319 270  25 375 103 207 338 119
#  206 206 244 377 322  23 203 251 321 203 385  23 327 324 377 385 366 287
#  167 251 350 350 377 316 330 248 304 129 184 168 130 403 130 116 130 354
#   78 405  37 238 184 139 239 280  38 360  71 304 116 364 276 250 254 262
#  152   9  29   9 254 276 138 141 138]

# %%
print(" \n parallel ----- \n") # needs more data to be efficient

sub2 = ns.SubSampler(y=v, row_sample=0.6, seed=123, n_jobs=2)
start = time()
y2 = sub2.subsample()
print(f"elapsed time: {time() - start}")

print(y2)

_ = plt.hist(y2, bins='auto')
plt.show()
# Out:
#
#  parallel -----
#
# creating breaks...
# main loop...
# 100%|██████████| 10/10 [00:00<00:00, 1420.31it/s]
# elapsed time: 0.03908061981201172
# [ 45 356 419 201 229 259 417 396  82 396 396 294 229 156 436 396 170  57
#   56  45 243  45 433 171 109  33 363 236 352 133 171 433 136 136 334 393
#  258 269  42 393 351 352 363 111 196 431 242 355 299 237  22 301 355 292
#  189 189 242 224 383 406 289 226 288 236 370 157 181  11 435 214 401 158
#  438 267 388 424 221 140 173 339 381   5 318 185 173 429  53  14 339 308
#  275  40 148 261  53  18 227 199  98 205 261 308 127 426 381 110 388 193
#   35 128 253 320  55   2   6  87  17  66  49 374  96 407 198 175 179  55
#  411  28  87 374 100 298 326 374   6 345 420  63 374 149 439  96 149 368
#   17  80 147  59 284 219 311  16 228 208  59 311 162 342 191 437 125 122
#   59 409 219  91  19 311 409 432 307  69 313 208 228 437 284 218 225 397
#  218 155 371 244 249 159 207  83 154   3 319 270  25 375 103 207 338 119
#  206 206 244 377 322  23 203 251 321 203 385  23 327 324 377 385 366 287
#  167 251 350 350 377 316 330 248 304 129 184 168 130 403 130 116 130 354
#   78 405  37 238 184 139 239 280  38 360  71 304 116 364 276 250 254 262
#  152   9  29   9 254 276 138 141 138]

# %%
print(f" \n check: {np.allclose(y1, y2)} \n")
# Out:
#
#  check: True

# %%
print(len(x1))
print(len(x2))
print(len(u))
print(len(y1))
print(len(y2))
print(len(v))
# Out:
# 1074
# 1074
# 1797
# 261
# 261
# 442

# %%
fig, axs = plt.subplots(2, 3)
axs[0, 0].hist(u[x1], bins='auto', density=True)
axs[0, 1].hist(u[x2], bins='auto', density=True)
axs[0, 2].hist(u, bins='auto', density=True)
axs[1, 0].hist(v[y1], bins='auto', density=True)
axs[1, 1].hist(v[y2], bins='auto', density=True)
axs[1, 2].hist(v, bins='auto', density=True)
# Out:
# (array([0.00267828, 0.00563849, 0.00479272, 0.00436983, 0.00352406,
#         0.00288973, 0.00267828, 0.00296021, 0.00119818, 0.00042289]),
#  array([ 25. ,  57.1,  89.2, 121.3, 153.4, 185.5, 217.6, 249.7, 281.8,
#         313.9, 346. ]),
#  <BarContainer object of 10 artists>)
